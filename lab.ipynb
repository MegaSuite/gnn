# %% [markdown]
# 挑战1：完成步骤一中的环境配置，使可以进行步骤二中的节点编码。
#
# 挑战2：代码漏洞检测是一个图级的二分类问题，它在对图节点编码的基础上，进一步得到图级的编码。
#
# 实现一个Readout层(src/process/model.py)，从节点编码得到代码图的编码表示，从而可以完成步骤三中的模型训练和评估。
#
# 挑战3：在使用所有训练数据条件下，修改代码的图表示或者模型，使模型的预测准确率达到55%以上(此挑战会根据准确率的提升酌情加分,最高满分)。

# %% [markdown]
# 一.环境安装
#
# 安装并激活python环境, 已经验证的版本是3.7.2
# ```
# python --version
# conda create -n devign python=3.7.2 #此命令不要重复执行，成功后可注释掉
# conda activate devign
# ```
# 安装torch、torch-geometric，具体安装方法参考 https://pytorch.org/get-started/locally/
#
# 安装当前试验所依赖的python包
# !pip install -r requirements.txt

# %%
# 原始的代码数据集存放在 data/raw (Paths.raw)中
# 每一条数据包含：
# project名，commit_id，target（是否为漏洞代码），func（函数代码文本）
# 我们探索一下原始数据的构成
import pandas as pd
dataset = pd.read_json("data/raw/dataset.json")
dataset.head(5)

# %% [markdown]
# 生成的代码图数据存放在data/cpg (Paths.cpg)中，其中每100条数据写入一个文件
#
# 解压代码图数据
#
# !tar -xvzf cpg.tar.gz

# %%
# 二.图节点代码文本编码
# 训练用于编码节点中文本的word2vec模型，并对节点的文本进行编码
import main
main.setup()
main.embed_task()

# %%
# 三.模型训练和验证
import main
main.process_task(True, False)
# Out:
# The model has 271,361 trainable parameters
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 2 to 665
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 6879 to 7686
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 7688 to 8327
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 8330 to 9005
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 9010 to 9614
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   105 non-null    object
#  1   target  105 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.2 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 9649 to 10449
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   97 non-null     object
#  1   target  97 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 10452 to 11029
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 11031 to 11665
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 11677 to 12421
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   97 non-null     object
#  1   target  97 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 12429 to 13199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 13205 to 13712
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 668 to 1372
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 13715 to 14355
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 14359 to 15157
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 15174 to 15908
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 15920 to 16972
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 16973 to 17585
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 17597 to 18330
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 18334 to 19124
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 19146 to 19836
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   105 non-null    object
#  1   target  105 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.2 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 103 entries, 19842 to 20565
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   103 non-null    object
#  1   target  103 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.0 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 20578 to 21227
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 1373 to 1962
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 21233 to 21947
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 21948 to 22608
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 22617 to 23254
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 23255 to 23929
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 23940 to 24609
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 24616 to 25299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 25303 to 25889
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 25894 to 26704
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 26716 to 27298
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   76 non-null     object
#  1   target  76 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 1964 to 2695
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   101 non-null    object
#  1   target  101 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 2701 to 3370
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 3382 to 4092
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   102 non-null    object
#  1   target  102 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.0 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 4095 to 4857
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 4862 to 5618
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 5619 to 6222
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   97 non-null     object
#  1   target  97 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 6244 to 6878
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 7.7 KB
# Splitting Dataset
# train with cpu.
# /root/gnnori/src/utils/objects/input_dataset.py:16: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   return DataLoader(dataset=self, batch_size=batch_size, shuffle=shuffle)
# Epoch 1; - Train Loss: 0.6943; Acc: 0.0379; - Validation Loss: 0.6916; Acc: 0.0; - Time: 22.153865337371826
# Validation loss decreased (inf --> 0.691559).  Saving model ...
#
# Epoch 2; - Train Loss: 0.6928; Acc: 0.0; - Validation Loss: 0.6905; Acc: 0.0; - Time: 40.445091009140015
# Validation loss decreased (0.691559 --> 0.690533).  Saving model ...
#
# Epoch 3; - Train Loss: 0.6927; Acc: 0.0; - Validation Loss: 0.6909; Acc: 0.0; - Time: 59.30227708816528
# EarlyStopping counter: 1 out of 15
#
# Epoch 4; - Train Loss: 0.6919; Acc: 0.0; - Validation Loss: 0.6883; Acc: 0.0; - Time: 77.6191041469574
# Validation loss decreased (0.690533 --> 0.688333).  Saving model ...
#
# Epoch 5; - Train Loss: 0.6912; Acc: 0.0388; - Validation Loss: 0.6885; Acc: 0.0; - Time: 95.2666711807251
# EarlyStopping counter: 1 out of 15
#
# Epoch 6; - Train Loss: 0.6911; Acc: 0.0; - Validation Loss: 0.69; Acc: 0.0; - Time: 114.3704617023468
# Epoch 56; - Train Loss: 0.6264; Acc: 0.0; - Validation Loss: 0.686; Acc: 0.0; - Time: 1019.6566045284271
# EarlyStopping counter: 2 out of 15
#
# Epoch 57; - Train Loss: 0.6201; Acc: 0.0; - Validation Loss: 0.6734; Acc: 0.0; - Time: 1037.315869808197
# EarlyStopping counter: 3 out of 15
#
# Epoch 58; - Train Loss: 0.6145; Acc: 0.04; - Validation Loss: 0.6749; Acc: 0.0; - Time: 1056.4356365203857
# EarlyStopping counter: 4 out of 15
#
# Epoch 59; - Train Loss: 0.6044; Acc: 0.0; - Validation Loss: 0.6736; Acc: 0.0; - Time: 1075.1078901290894
# EarlyStopping counter: 5 out of 15
#
# Epoch 60; - Train Loss: 0.5963; Acc: 0.0; - Validation Loss: 0.6634; Acc: 0.0; - Time: 1093.3300371170044
# EarlyStopping counter: 6 out of 15
#
# Epoch 61; - Train Loss: 0.6002; Acc: 0.0373; - Validation Loss: 0.6932; Acc: 0.0; - Time: 1111.3652203083038
# EarlyStopping counter: 7 out of 15
#
# Epoch 62; - Train Loss: 0.6048; Acc: 0.0; - Validation Loss: 0.7052; Acc: 0.0; - Time: 1129.997724056244
# EarlyStopping counter: 8 out of 15
#
# Epoch 63; - Train Loss: 0.6046; Acc: 0.0; - Validation Loss: 0.6926; Acc: 0.0; - Time: 1148.849437713623
# EarlyStopping counter: 9 out of 15
#
# Epoch 64; - Train Loss: 0.598; Acc: 0.0; - Validation Loss: 0.669; Acc: 0.0; - Time: 1167.9405925273895
# EarlyStopping counter: 10 out of 15
#
# Epoch 65; - Train Loss: 0.6052; Acc: 0.0629; - Validation Loss: 0.6838; Acc: 0.2115; - Time: 1185.9971945285797
# EarlyStopping counter: 11 out of 15
#
# Epoch 66; - Train Loss: 0.6051; Acc: 0.0; - Validation Loss: 0.6892; Acc: 0.0; - Time: 1205.1664125919342
# EarlyStopping counter: 12 out of 15
#
# Epoch 67; - Train Loss: 0.5857; Acc: 0.0; - Validation Loss: 0.6692; Acc: 0.0; - Time: 1223.9554080963135
# EarlyStopping counter: 13 out of 15
#
# Epoch 68; - Train Loss: 0.5852; Acc: 0.0; - Validation Loss: 0.6641; Acc: 0.0; - Time: 1242.325937986374
# EarlyStopping counter: 14 out of 15
#
# Epoch 69; - Train Loss: 0.5679; Acc: 0.0; - Validation Loss: 0.6636; Acc: 0.0; - Time: 1261.1747612953186
# EarlyStopping counter: 15 out of 15
# Early stopping
# Testing
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 381    1
# 382    0
# 383    0
# 384    0
# 385    1
# Length: 386, dtype: int64
#
# Confusion matrix:
# [[119  78]
#  [ 92  97]]
# TP: 97, FP: 78, TN: 119, FN: 92
# Accuracy: 0.5595854922279793
# Precision: 0.5542857142857143
# Recall: 0.5132275132275133
# F-measure: 0.532967032967033
# Precision-Recall AUC: 0.5752987695397689
# AUC: 0.6085998979399995
# MCC: 0.1177765761089248
# Error: 88.94098273071499
